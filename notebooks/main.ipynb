# %%
import pandas as pd
import numpy as np
import time

# %%
cd ..
# Out:
# D:\git_repos\lab_data_science2

# %%
import src.config as cfg

# %%
path_to_train_data = './data/raw/train.csv'

# %%
df_train = pd.read_csv(path_to_train_data)
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# df_train = df_train.drop(['Alley', ], axis=1)
# df_train

# %%
df_train['Alley'] = df_train['Alley'].fillna('NoAlley')
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  NoAlley
# 1        2          20       RL         80.0     9600   Pave  NoAlley
# 2        3          60       RL         68.0    11250   Pave  NoAlley
# 3        4          70       RL         60.0     9550   Pave  NoAlley
# 4        5          60       RL         84.0    14260   Pave  NoAlley
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  NoAlley
# 1456  1457          20       RL         85.0    13175   Pave  NoAlley
# 1457  1458          70       RL         66.0     9042   Pave  NoAlley
# 1458  1459          20       RL         68.0     9717   Pave  NoAlley
# 1459  1460          20       RL         75.0     9937   Pave  NoAlley
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
def feature_distribution_types(df, display=True):
    continuous_features = list(df.select_dtypes(include=['int64', 'float64', 'uint8']).columns)
    categorical_features = list(df.select_dtypes(include=['object', 'bool']).columns)
    if display:
        print(f"Continuous Features={continuous_features}\n")
        print(f"Categorical Features={categorical_features}")
    return continuous_features, categorical_features

# %%
continuous_features, categorical_features = feature_distribution_types(df_train)
# Out:
# Continuous Features=['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
#
# ...

# %%
dups = df_train.duplicated()
print(dups.sum())
# Out:
# 0

# %%
def eval_features(df):
    ## Separate Categorical and Numerical Features
    categorical_features = list(
        df.select_dtypes(include=["category", "object"]).columns
    )
    continuous_features = list(df.select_dtypes(include=["number"]).columns)

    print(f"Continuous features: {continuous_features}")
    print(f"Categorical features: {categorical_features}")
    print("\n --- Cardinality of Categorical Features ---\n")

    for feature in categorical_features:
        cardinality = df[feature].nunique()
        if cardinality < 10:
            print(f"{feature}: cardinality={cardinality}, {df[feature].unique()}")
        else:
            print(f"{feature}: cardinality={cardinality}")
    all_features = categorical_features + continuous_features
    return all_features, categorical_features, continuous_features

# %%
all_features, categorical_features, continuous_features = eval_features(df_train)
# Out:
# Continuous features: ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
# ...

# %%
def show_feature_importance(feature_importance_lst):
    fis_df = pd.concat(feature_importance_lst, axis=1)
    fis_df.sort_values("0_importance", ascending=True).head(40).plot(
        kind="barh", figsize=(12, 12), title="Feature Importance Across Folds"
    )
    plt.show()

# %%
def show_missing_features(df):
    missing_vals = df.isna().sum().sort_values(ascending=False)
    print(missing_vals[missing_vals > 0])

# %%
show_missing_features(df_train)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageQual        81
# GarageCond        81
# GarageFinish      81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtFinType1      37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
#PREPROCESS

# %%
missing_vals = df_train.isna().sum()
# print(missing_vals[missing_vals > 0])
missing_vals[missing_vals > 0]
# Out:
# LotFrontage      259
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
cont_features, cat_features = feature_distribution_types(df_train, display=True)

cont_features.remove(cfg.TARGET)
# Out:
# Continuous Features=['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
#
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn import linear_model

imputer = SimpleImputer(strategy="most_frequent")

df_train[cat_features] = imputer.fit_transform(df_train[cat_features])
# test[cat_features] = imputer.transform(test[cat_features])

# %%
# imputer = SimpleImputer(strategy="mean")
imputer = SimpleImputer(strategy="median")  # median is more robust to outliers
df_train[cont_features] = imputer.fit_transform(df_train[cont_features])
# test[cont_features] = imputer.transform(test[cont_features])

# %%
def label_encoder(columns, train, test=None):
    for col in columns:
        train[col] = train[col].astype(str)
        train[col] = preprocessing.LabelEncoder().fit_transform(train[col])
        if test != None:
            test[col] = test[col].astype(str)
            test[col] = preprocessing.LabelEncoder().transform(test[col])
    if test != None:
        return train, test
    return train

# %%
from sklearn import preprocessing

# %%
train = label_encoder(cat_features, df_train)

# %%
train
# Out:
#           Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1.0        60.0         3         65.0   8450.0       1      1
# 1        2.0        20.0         3         80.0   9600.0       1      1
# 2        3.0        60.0         3         68.0  11250.0       1      1
# 3        4.0        70.0         3         60.0   9550.0       1      1
# 4        5.0        60.0         3         84.0  14260.0       1      1
# ...      ...         ...       ...          ...      ...     ...    ...
# 1455  1456.0        60.0         3         62.0   7917.0       1      1
# 1456  1457.0        20.0         3         85.0  13175.0       1      1
# 1457  1458.0        70.0         3         66.0   9042.0       1      1
# 1458  1459.0        20.0         3         68.0   9717.0       1      1
# 1459  1460.0        20.0         3         75.0   9937.0       1      1
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
FEATURES = cont_features + cat_features

# %%
def create_folds(df, TARGET, n_folds=5, seed=42):
    print(f"TARGET={TARGET}, n_folds={n_folds}, seed={seed}")
    df["fold"] = -1

    kf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)
    # kf = GroupKFold(n_splits=Config.N_FOLDS)

    for fold, (train_idx, valid_idx) in enumerate(kf.split(df, df[TARGET])):
        df.loc[valid_idx, "fold"] = fold

    # df.to_csv(f"train_fold{num_folds}.csv", index=False)
    return df

# %%
def train_cv_model(
    df,
    get_model_fn,
    FEATURES,
    TARGET,
    calc_probability,
    rowid,
    params,
    n_folds=5,
    seed=42,
):

    final_valid_predictions = {}
    fold_scores = []  # Scores of Validation Set
    feature_importance_lst = []

    for fold in range(n_folds):
        print(10 * "=", f"Fold {fold+1}/{n_folds}", 10 * "=")

        start_time = time.time()

        xtrain = df[df.fold != fold].reset_index(
            drop=True
        )  # Everything not in validation fold
        xvalid = df[df.fold == fold].reset_index(drop=True)

        valid_ids = xvalid.Id.values.tolist()  # Id's of everything in validation fold

        ytrain = xtrain[TARGET]
        yvalid = xvalid[TARGET]

        xtrain = xtrain[FEATURES]
        xvalid = xvalid[FEATURES]
        xtrain.head()

        model = get_model_fn()

        model.fit(
            xtrain,
            ytrain,
        )

        # Mean of the predictions
        #         preds_valid = model.predict(xvalid)
        #         test_preds = model.predict(xtest)
        if calc_probability:
            preds_valid = model.predict_proba(xvalid)[:, 1]
        else:
            preds_valid = model.predict(xvalid)

        preds_valid_class = model.predict(xvalid)
        
        final_valid_predictions.update(dict(zip(valid_ids, preds_valid)))

#         fold_score = metrics.accuracy_score(yvalid, preds_valid)  # Validation Set Score
#         fold_score = metrics.roc_auc_score(yvalid, preds_valid)  # Validation Set Score
        fold_score = metrics.mean_absolute_error(
            yvalid, preds_valid
        )  # Validation Set 
        fold_scores.append(fold_score)
        #         importance_list.append(model.coef_.ravel())

        # Feature importance
#         fi = pd.DataFrame(
#             index=FEATURES,
#             data=model.coef_.ravel(),
#             columns=[f"{fold}_importance"],
#         )
#         feature_importance_lst.append(fi)

        run_time = time.time() - start_time

        print(f"fold: {fold+1}, Accuracy: {fold_score}, Run Time: {run_time:.2f}")

    return (
        model,
#         feature_importance_lst,
        fold_scores,
        final_valid_predictions,
    )

# %%
def get_linear_regression_model():
#     model = LogisticRegression(
#         max_iter=1000, C=0.0001, penalty="l2", solver="newton-cg"
#     )
    model = linear_model.LinearRegression()
    return model

# %%
train = create_folds(train, cfg.TARGET, cfg.Config.N_FOLDS)
# Out:
# TARGET=SalePrice, n_folds=5, seed=42
# C:\git\lab_data_science\venv\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
from sklearn import model_selection, metrics

# %%
(
    model,
#     feature_importance_lst,
    fold_scores,
    final_valid_predictions,
) = train_cv_model(
    train,
    get_linear_regression_model,
    FEATURES,
    cfg.TARGET,
    cfg.Config.calc_probability,
    "id",
    {},
    cfg.Config.N_FOLDS,
    cfg.Config.seed,
)
# Out:
# ========== Fold 1/5 ==========
# fold: 1, Accuracy: 22774.25669036867, Run Time: 0.08
# ========== Fold 2/5 ==========
# fold: 2, Accuracy: 20336.494893835556, Run Time: 0.03
# ========== Fold 3/5 ==========
# fold: 3, Accuracy: 20210.797139798775, Run Time: 0.03
# ========== Fold 4/5 ==========
# fold: 4, Accuracy: 20759.741591368413, Run Time: 0.03
# ========== Fold 5/5 ==========
# fold: 5, Accuracy: 21008.188094909085, Run Time: 0.03

# %%
import catboost

# %%
def get_catboost_regressor():
    model = catboost.CatBoostRegressor(iterations=1000,
                                       learning_rate=0.01,
                                       depth=5, 
                                      cat_features=cfg.CAT_COLS,
                                      verbose=100)
    return model

# %%
(
    catBoostModel,
#     feature_importance_lst,
    fold_scores,
    final_valid_predictions,
) = train_cv_model(
    train,
    get_catboost_regressor,
    FEATURES,
    cfg.TARGET,
    cfg.Config.calc_probability,
    "id",
    {},
    cfg.Config.N_FOLDS,
    cfg.Config.seed,
)
# Out:
# ========== Fold 1/5 ==========
# 0:	learn: 79753.1021808	total: 22.5ms	remaining: 22.4s
# C:\git\lab_data_science\venv\lib\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# 100:	learn: 46708.6167961	total: 2.92s	remaining: 26s
# 200:	learn: 32540.3892813	total: 5.63s	remaining: 22.4s
# 300:	learn: 26165.2473712	total: 8.34s	remaining: 19.4s
# 400:	learn: 23024.4254455	total: 11.2s	remaining: 16.7s
# 500:	learn: 20958.8433907	total: 14s	remaining: 13.9s
# 600:	learn: 19621.8765922	total: 16.9s	remaining: 11.2s
# 700:	learn: 18705.5554934	total: 19.6s	remaining: 8.37s
# 800:	learn: 17975.1712703	total: 22.3s	remaining: 5.53s
# 900:	learn: 17431.8216052	total: 25.2s	remaining: 2.77s
# 999:	learn: 16983.0064640	total: 28s	remaining: 0us
# ...

# %%
def get_catboost_regressor():
    model = catboost.CatBoostRegressor(iterations=2,
                                       learning_rate=0.01,
                                       depth=5, 
                                      cat_features=cfg.CAT_COLS,
                                      verbose=100)
    return model

(
    catBoostModel,
#     feature_importance_lst,
    fold_scores,
    final_valid_predictions,
) = train_cv_model(
    train,
    get_catboost_regressor,
    FEATURES,
    cfg.TARGET,
    cfg.Config.calc_probability,
    "id",
    {},
    cfg.Config.N_FOLDS,
    cfg.Config.seed,
)
# Out:
# ========== Fold 1/5 ==========
# 0:	learn: 79701.7704188	total: 15.6ms	remaining: 15.6ms
# 1:	learn: 79202.7436124	total: 32.9ms	remaining: 0us
# fold: 1, Accuracy: 56510.125143672216, Run Time: 0.11
# ========== Fold 2/5 ==========
# 0:	learn: 80010.8281248	total: 15.1ms	remaining: 15.1ms
# 1:	learn: 79525.0154102	total: 31.2ms	remaining: 0us
# C:\git\lab_data_science\venv\lib\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# C:\git\lab_data_science\venv\lib\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# ...
